# %%
# %pip install google-adk

import requests
from google.adk.agents import Agent

def call_mcp(session_id: str) -> dict:
    """Example function to call your MCP endpoint."""
    url = f"https://fi-mcp-dev-446597266106.europe-west1.run.app/mockWebPage?sessionId={session_id}"
    #url = f"https://fi-mcp-dev-446597266106.europe-west1.run.app/mockWebPage?sessionId={'a555e28f-1473-43c8-80e6-581ea48f482e'}"
    payload = {
    'phone': '4444444444',
    'otp': '00000'
     }
    url = requests.post("https://fi-mcp-dev-446597266106.europe-west1.run.app/mockWebPage?sessionId={session_id}", data=payload)
    #response = requests.get(url)
    response = requests.get(url)
    if response.status_code == 200:
        return {"status": "success", "data": response.text}
    else:
        return {"status": "error", "message": f"HTTP {response.status_code}"}

# Register the agent
root_agent = Agent(
    name="mcp_agent",
    model="gemini-2.0-flash",  # Or another Gemini model
    description="Agent to interact with fi-mcp server via HTTP.",
    instruction="Respond to queries by reaching out to the MCP server using the provided session ID, phone number and OTP.",
    tools=[call_mcp]
)
# Out:
# Requirement already satisfied: google-adk in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: PyYAML>=6.0.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (6.0.2)
# Requirement already satisfied: anyio>=4.9.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (4.9.0)
# Requirement already satisfied: authlib>=1.5.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (1.6.1)
# Requirement already satisfied: click>=8.1.8 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (8.2.1)
# Requirement already satisfied: fastapi>=0.115.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (0.116.1)
# Requirement already satisfied: google-api-python-client>=2.157.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (2.176.0)
# Requirement already satisfied: google-cloud-aiplatform>=1.95.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (1.104.0)
# Requirement already satisfied: google-cloud-secret-manager>=2.22.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (2.24.0)
# Requirement already satisfied: google-cloud-speech>=2.30.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (2.33.0)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.18.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (2.19.0)
# Requirement already satisfied: google-genai>=1.21.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (1.26.0)
# Requirement already satisfied: graphviz>=0.20.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp>=1.8.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (1.12.1)
# Requirement already satisfied: opentelemetry-api>=1.31.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (1.35.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace>=1.9.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (1.9.0)
# Requirement already satisfied: opentelemetry-sdk>=1.31.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (1.35.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (2.11.7)
# Requirement already satisfied: python-dateutil>=2.9.0.post0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv>=1.0.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (1.1.1)
# Requirement already satisfied: requests>=2.32.4 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (2.32.4)
# Requirement already satisfied: sqlalchemy>=2.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (2.0.41)
# Requirement already satisfied: starlette>=0.46.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (0.47.2)
# Requirement already satisfied: tenacity>=8.0.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (8.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (4.14.1)
# Requirement already satisfied: tzlocal>=5.3 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn>=0.34.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (0.35.0)
# Requirement already satisfied: watchdog>=6.0.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets>=15.0.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from anyio>=4.9.0->google-adk) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from anyio>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from authlib>=1.5.1->google-adk) (45.0.5)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-api-python-client>=2.157.0->google-adk) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-api-python-client>=2.157.0->google-adk) (2.40.3)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-api-python-client>=2.157.0->google-adk) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-api-python-client>=2.157.0->google-adk) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-api-python-client>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (6.31.1)
# Requirement already satisfied: packaging>=14.3 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (3.35.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (2.1.1)
# Requirement already satisfied: docstring_parser<1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (0.17.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (3.1.1)
# Requirement already satisfied: google-cloud-trace<2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (1.16.2)
# Requirement already satisfied: google-cloud-logging<4 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (3.12.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-secret-manager>=2.22.0->google-adk) (0.14.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-storage<3.0.0,>=2.18.0->google-adk) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-storage<3.0.0,>=2.18.0->google-adk) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-storage<3.0.0,>=2.18.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-genai>=1.21.1->google-adk) (0.28.1)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from mcp>=1.8.0->google-adk) (0.4.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from mcp>=1.8.0->google-adk) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from mcp>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from mcp>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from mcp>=1.8.0->google-adk) (2.4.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.31.0->google-adk) (8.7.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp==1.*,>=1.5.0dev0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-gcp-trace>=1.9.0->google-adk) (1.9.0a0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.31.0->google-adk) (0.56b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from python-dateutil>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from requests>=2.32.4->google-adk) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from requests>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from requests>=2.32.4->google-adk) (2025.7.14)
# Requirement already satisfied: h11>=0.8 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from uvicorn>=0.34.0->google-adk) (0.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=2.157.0->google-adk) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (1.73.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=2.157.0->google-adk) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (1.6.2)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (0.3.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=2.157.0->google-adk) (3.2.3)
# Requirement already satisfied: httpcore==1.* in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai>=1.21.1->google-adk) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.31.0->google-adk) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.8.0->google-adk) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.8.0->google-adk) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.8.0->google-adk) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.8.0->google-adk) (0.26.0)
# Requirement already satisfied: numpy>=1.21 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from shapely<3.0.0->google-cloud-aiplatform>=1.95.1->google-cloud-aiplatform[agent-engines]>=1.95.1->google-adk) (2.3.1)
# Requirement already satisfied: cffi>=1.14 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from cryptography->authlib>=1.5.1->google-adk) (1.17.1)
# Requirement already satisfied: pycparser in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from cffi>=1.14->cryptography->authlib>=1.5.1->google-adk) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=2.157.0->google-adk) (0.6.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !adk web
# Out:
# /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages/google/adk/cli/fast_api.py:365: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [45254]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://localhost:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:52556 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:52556 - "GET /dev-ui/ HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52556 - "GET /dev-ui/chunk-EQDQRRRY.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52556 - "GET /dev-ui/polyfills-B6TNHZQ6.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52557 - "GET /dev-ui/main-SRBSE46V.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52557 - "GET /dev-ui/styles-4VDSPQ37.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52557 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:52557 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52557 - "GET /dev-ui/assets/ADK-512-color.svg HTTP/1.1" 304 Not Modified
# ^C
# INFO:     Shutting down
# INFO:     Finished server process [45254]
# ERROR:    Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 674, in run_until_complete
#     self.run_forever()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/opt/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#   File "/opt/anaconda3/lib/python3.12/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/Users/vishalj/Downloads/GAgent/.venv/lib/python3.12/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError
#
#
# Aborted!
