# %% [markdown]
# <a href="https://colab.research.google.com/github/vishal0882/DataScience/blob/main/Getting_started_with_BigQuery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Before you begin
#
#
# 1.   Use the [Cloud Resource Manager](https://console.cloud.google.com/cloud-resource-manager) to Create a Cloud Platform project if you do not already have one.
# 2.   [Enable billing](https://support.google.com/cloud/answer/6293499#enable-billing) for the project.
# 3.   [Enable BigQuery](https://console.cloud.google.com/flows/enableapi?apiid=bigquery) APIs for the project.

# %% [markdown]
# ### Provide your credentials to the runtime

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ### Declare the Cloud project ID which will be used throughout this notebook

# %%
project_id = '[your project ID]'

# %% [markdown]
# ### Optional: Enable data table display
#
# Colab includes the ``google.colab.data_table`` package that can be used to display large pandas dataframes as an interactive data table.
# It can be enabled with:

# %%
# %load_ext google.colab.data_table

# %% [markdown]
# If you would prefer to return to the classic Pandas dataframe display, you can disable this by running:
# ```python
# %unload_ext google.colab.data_table
# ```

# %% [markdown]
# # Use BigQuery via magics
#
# The `google.cloud.bigquery` library also includes a magic command which runs a query and either displays the result or saves it to a variable as a `DataFrame`.

# %%
# Display query output immediately

# %%bigquery --project {project_id}
SELECT
  COUNT(*) as total_rows
FROM `bigquery-public-data.samples.gsod`
# Out:
#    total_rows
# 0   114420316

# %%
# Save output in a variable `df`

# %%bigquery df --project {project_id}
SELECT
  COUNT(*) as total_rows
FROM `bigquery-public-data.samples.gsod`

# %%
df
# Out:
#    total_rows
# 0   114420316

# %% [markdown]
# # Use BigQuery through BigQuery DataFrames
#
# See [BigQuery documentation](https://cloud.google.com/bigquery/docs) and [BigQuery DataFrames reference documentation](https://cloud.google.com/python/docs/reference/bigframes/latest).
#
# The [GSOD sample table](https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=samples&t=gsod&page=table) contains weather information collected by NOAA, such as precipitation amounts and wind speeds from late 1929 to early 2010.

# %% [markdown]
# ### Sample approximately 2000 random rows

# %%
import bigframes.pandas as bpd

bpd.options.bigquery.project = project_id

sample_count = 2000

df = bpd.read_gbq("bigquery-public-data.samples.gsod")

row_count = df.shape[0]

df = df.sample(sample_count)

print('Full dataset has %d rows' % row_count)
# Out:
# Full dataset has 114420316 rows

# %% [markdown]
# ### Describe the sampled data

# %%
df.describe()
# Out:
# Query job 31a2be00-ff90-4ae6-b393-b13b55962f66 is DONE. 17.3 GB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:31a2be00-ff90-4ae6-b393-b13b55962f66&page=queryresults">Open Job</a>
#        station_number   wban_number       year     month       day  \
# count          2000.0        2000.0     2000.0    2000.0    2000.0
# mean       509229.928    91090.3395  1987.1865    6.5395    16.016
# std     301968.506371  25341.066819  16.104204  3.424953  8.722717
# min           10070.0        3103.0     1936.0       1.0       1.0
# 25%          236910.0       99999.0     1977.0       4.0       9.0
# 50%          542920.0       99999.0     1989.0       6.0      16.0
# 75%          725090.0       99999.0     2001.0      10.0      23.0
# max          999999.0       99999.0     2010.0      12.0      31.0
#
#         mean_temp  num_mean_temp_samples  mean_dew_point  \
# count      2000.0                 2000.0          1905.0
# mean       52.792                12.9165       42.083045
# std     23.463624               7.867431       22.223635
# min    -52.900002                    4.0      -57.299999
# 25%     39.599998                    7.0       29.700001
# 50%          55.0                    8.0            43.5
# 75%          70.0                   23.0            57.5
# max    101.400002                   24.0       81.800003
#
#        num_mean_dew_point_samples  mean_sealevel_pressure  ...  \
# count                      1905.0                  1503.0  ...
# mean                    12.740682             1014.776314  ...
# std                       7.84855                9.095351  ...
# min                           4.0                   959.5  ...
# 25%                           7.0             1009.400024  ...
# 50%                           8.0                  1014.5  ...
# 75%                          23.0             1020.099976  ...
# max                          24.0             1055.699951  ...
#
#        mean_visibility  num_mean_visibility_samples  mean_wind_speed  \
# count           1784.0                       1784.0           1977.0
# mean         12.512332                    12.556614         6.718816
# std           9.736078                     7.797144         4.952929
# min                0.0                          4.0              0.0
# 25%                6.5                          6.0              3.3
# 50%                9.9                          8.0              5.8
# 75%               15.0                         23.0              8.9
# max          99.400002                         24.0             53.5
#
#        num_mean_wind_speed_samples  max_sustained_wind_speed  \
# count                       1977.0                    1944.0
# mean                     12.843703                 12.149588
# std                       7.847506                  7.031532
# min                            4.0                       1.0
# 25%                            7.0                       7.8
# 50%                            8.0                      11.1
# 75%                           23.0                      15.5
# max                           24.0                      88.0
#
#        max_gust_wind_speed  max_temperature  min_temperature  \
# count                272.0           2000.0              0.0
# mean             25.480882         44.03815             <NA>
# std               9.874374        23.735059             <NA>
# min                    8.0       -61.799999             <NA>
# 25%                   19.0             32.0             <NA>
# 50%              23.299999        46.400002             <NA>
# 75%                   29.9        60.799999             <NA>
# max                   89.0             91.0             <NA>
#
#        total_precipitation  snow_depth
# count               1819.0       103.0
# mean               0.08061        10.0
# std               0.288874   11.402837
# min                    0.0         0.4
# 25%                    0.0         2.4
# 50%                    0.0         5.9
# 75%                   0.01        15.0
# max                   3.54   82.699997
#
# [8 rows x 23 columns]

# %% [markdown]
# ### View arbitrary 10 rows

# %%
df.peek(10)
# Out:
# Query job f04ed791-d4f8-4415-b8c3-941f30aa2f10 is DONE. 17.3 GB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:f04ed791-d4f8-4415-b8c3-941f30aa2f10&page=queryresults">Open Job</a>
# Query job 52a52256-5fb2-4cd4-9710-8c0c71e44f8a is DONE. 317.7 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:52a52256-5fb2-4cd4-9710-8c0c71e44f8a&page=queryresults">Open Job</a>
# Warning: Total number of columns (31) exceeds max_columns (20). Falling back to pandas display.
#            station_number  wban_number  year  month  day  mean_temp  \
# 35349954           638870        99999  1961      6    8  68.599998
# 2497913            543370        99999  1982      3   27  38.400002
# 46805715            38660        99999  1989      9   14  58.799999
# 45388121           713970        99999  1984      7   31  69.300003
# 105768579          287040        99999  1969     11    1       32.0
# 49492447            10250        99999  1996      8   18  51.200001
# 45658252           161150        99999  1994      7   14  75.800003
# 99477822           281310        99999  1981     11    8  30.200001
# 77950004           722926         3154  1996     12    8       57.5
# 99829908           107710        99999  2002      7   28  69.699997
#
#            num_mean_temp_samples  mean_dew_point  num_mean_dew_point_samples  \
# 35349954                       5            47.0                           5
# 2497913                        8       28.799999                           8
# 46805715                      22            54.0                          22
# 45388121                      24       57.099998                          24
# 105768579                      8            29.4                           8
# 49492447                      24       47.400002                          24
# 45658252                      13       70.400002                          13
# 99477822                       7            25.1                           6
# 77950004                      24       44.200001                          21
# 99829908                      16       55.200001                          16
#
#            mean_sealevel_pressure  ...  min_temperature  \
# 35349954                     <NA>  ...             <NA>
# 2497913               1026.099976  ...             <NA>
# 46805715                     <NA>  ...             <NA>
# 45388121              1017.900024  ...             <NA>
# 105768579             1002.700012  ...             <NA>
# 49492447              1010.900024  ...             <NA>
# 45658252                     <NA>  ...             <NA>
# 99477822                   1020.5  ...             <NA>
# 77950004              1019.200012  ...             <NA>
# 99829908              1020.700012  ...             <NA>
#
#            min_temperature_explicit  total_precipitation  snow_depth    fog  \
# 35349954                       <NA>                  0.0        <NA>  False
# 2497913                        <NA>                 0.04        <NA>  False
# 46805715                       <NA>                 <NA>        <NA>  False
# 45388121                       <NA>                  0.0        <NA>  False
# 105768579                      <NA>                  0.0        <NA>  False
# 49492447                       <NA>                 0.12        <NA>  False
# 45658252                       <NA>                  0.0        <NA>  False
# 99477822                       <NA>                  0.0        <NA>  False
# 77950004                       <NA>                  0.0        <NA>  False
# 99829908                       <NA>                  0.0        <NA>  False
#
#             rain   snow   hail  thunder  tornado
# 35349954   False  False  False    False    False
# 2497913    False  False  False    False    False
# 46805715   False  False  False    False    False
# 45388121   False  False  False    False    False
# 105768579  False  False  False    False    False
# 49492447   False  False  False    False    False
# 45658252   False  False  False    False    False
# 99477822   False  False  False    False    False
# 77950004   False  False  False    False    False
# 99829908   False  False  False    False    False
#
# [10 rows x 31 columns]

# %% [markdown]
# ### View 10 highest total_precipitation samples

# %%
df.sort_values('total_precipitation', ascending=False).head(10)[['station_number', 'year', 'month', 'day', 'total_precipitation']]
# Out:
# Query job c44ce499-32e4-4548-b5e3-59ef653c93f5 is DONE. 110.6 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=bigframes-dev&j=bq:US:c44ce499-32e4-4548-b5e3-59ef653c93f5&page=queryresults">Open Job</a>
#            station_number  year  month  day  total_precipitation
# 48210163           722140  1976     11   28                 3.54
# 100473809          322460  1961      3   26                 2.95
# 96170642           972600  1979      3    1                 2.76
# 61880958           476550  1961      4   26                 2.72
# 43527842           619740  1983     10   16                  2.6
# 34344262           964210  1996      4   29                 2.56
# 43236540           483280  1986      5   23                 2.52
# 114338091          851230  2005      3   19                 2.44
# 104373932           82150  1989     11   20                 2.36
# 35250392           471065  1975      7   24                 2.36
#
# [10 rows x 5 columns]

# %% [markdown]
# # Use BigQuery through google-cloud-bigquery
#
# See [BigQuery documentation](https://cloud.google.com/bigquery/docs) and [library reference documentation](https://googlecloudplatform.github.io/google-cloud-python/latest/bigquery/usage.html).
#
# The [GSOD sample table](https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=samples&t=gsod&page=table) contains weather information collected by NOAA, such as precipitation amounts and wind speeds from late 1929 to early 2010.

# %% [markdown]
# ### Sample approximately 2000 random rows

# %%
from google.cloud import bigquery

client = bigquery.Client(project=project_id)

sample_count = 2000
row_count = client.query('''
  SELECT
    COUNT(*) as total
  FROM `bigquery-public-data.samples.gsod`''').to_dataframe().total[0]

df = client.query('''
  SELECT
    *
  FROM
    `bigquery-public-data.samples.gsod`
  WHERE RAND() < %d/%d
''' % (sample_count, row_count)).to_dataframe()

print('Full dataset has %d rows' % row_count)
# Out:
# Full dataset has 114420316 rows

# %% [markdown]
# ### Describe the sampled data

# %%
df.describe()
# Out:
# Warning: Total number of columns (23) exceeds max_columns (20). Falling back to pandas display.
#        station_number   wban_number         year     month        day  \
# count          1917.0        1917.0       1917.0    1917.0     1917.0
# mean    502447.478352  89822.252478  1986.604591  6.489828  15.766823
# std     299118.262175  27008.869915    16.451458  3.453014   8.841116
# min           10015.0           6.0       1932.0       1.0        1.0
# 25%          235270.0       99999.0       1977.0       3.0        8.0
# 50%          532760.0       99999.0       1989.0       6.0       16.0
# 75%          724555.0       99999.0       2000.0      10.0       24.0
# max          999999.0       99999.0       2010.0      12.0       31.0
#
#          mean_temp  num_mean_temp_samples  mean_dew_point  \
# count  1917.000000                 1917.0     1837.000000
# mean     51.783516              13.098592       41.707730
# std      24.125164               7.974397       22.294639
# min     -88.599998                    4.0      -64.500000
# 25%      37.000000                    7.0       28.900000
# 50%      54.500000                    8.0       44.099998
# 75%      70.199997                   24.0       57.299999
# max      98.500000                   24.0       79.800003
#
#        num_mean_dew_point_samples  mean_sealevel_pressure  ...  \
# count                      1837.0             1428.000000  ...
# mean                    13.045727             1014.851050  ...
# std                      7.981465                9.420865  ...
# min                           4.0              966.000000  ...
# 25%                           7.0             1009.599976  ...
# 50%                           8.0             1014.599976  ...
# 75%                          23.0             1020.099976  ...
# max                          24.0             1059.800049  ...
#
#        mean_visibility  num_mean_visibility_samples  mean_wind_speed  \
# count      1723.000000                       1723.0      1894.000000
# mean         11.872838                    12.859547         6.969799
# std           9.545982                     7.936962         4.987575
# min           0.000000                          4.0         0.000000
# 25%           6.300000                          7.0         3.500000
# 50%           9.300000                          8.0         6.000000
# 75%          14.600000                         23.0         9.200000
# max          99.400002                         24.0        46.400002
#
#        num_mean_wind_speed_samples  max_sustained_wind_speed  \
# count                       1894.0               1858.000000
# mean                     13.047518                 12.337675
# std                       7.953833                  6.642102
# min                            4.0                  1.000000
# 25%                            7.0                  7.800000
# 50%                            8.0                 11.700000
# 75%                           23.0                 15.500000
# max                           24.0                 68.000000
#
#        max_gust_wind_speed  max_temperature  min_temperature  \
# count           258.000000      1915.000000              0.0
# mean             24.364341        43.315718              NaN
# std               9.405444        24.079599              NaN
# min               5.800000       -94.500000              NaN
# 25%              18.100000        30.200001              NaN
# 50%              22.900000        46.000000              NaN
# 75%              28.000000        60.299999              NaN
# max              62.200001        91.599998              NaN
#
#        total_precipitation  snow_depth
# count          1745.000000  108.000000
# mean              0.068115    9.568518
# std               0.264338    8.773491
# min               0.000000    0.400000
# 25%               0.000000    2.000000
# 50%               0.000000    6.700000
# 75%               0.010000   13.400000
# max               4.530000   34.599998
#
# [8 rows x 23 columns]

# %% [markdown]
# ### View the first 10 rows

# %%
df.head(10)
# Out:
# Warning: Total number of columns (31) exceeds max_columns (20). Falling back to pandas display.
#    station_number  wban_number  year  month  day  mean_temp  \
# 0          942030        99999  1948      2   15  81.000000
# 1          722580        13960  1953      8   14  86.800003
# 2          725430        94822  1975      5   12  55.400002
# 3          299150        99999  1979      8   31  71.900002
# 4          310040        99999  1986     12   27 -37.299999
# 5          370470        99999  1987     10   14  50.099998
# 6          725127         4726  1989      1    6  25.299999
# 7          684380        99999  1994      7    1  38.599998
# 8          443020        99999  1994     12   11   0.100000
# 9          110320        99999  1994     12   11  45.599998
#
#    num_mean_temp_samples  mean_dew_point  num_mean_dew_point_samples  \
# 0                      7       76.900002                           7
# 1                     24       70.800003                          24
# 2                     24       42.200001                          24
# 3                      6       52.099998                           6
# 4                      6      -43.500000                           6
# 5                      6       45.599998                           6
# 6                     18       22.100000                          18
# 7                      6       20.799999                           6
# 8                      7       -3.100000                           7
# 9                      8       43.799999                           8
#
#    mean_sealevel_pressure  ...  min_temperature  min_temperature_explicit  \
# 0                     NaN  ...              NaN                      <NA>
# 1             1016.799988  ...              NaN                      <NA>
# 2             1013.200012  ...              NaN                      <NA>
# 3             1017.200012  ...              NaN                      <NA>
# 4             1047.500000  ...              NaN                      <NA>
# 5             1023.900024  ...              NaN                      <NA>
# 6                     NaN  ...              NaN                      <NA>
# 7                     NaN  ...              NaN                      <NA>
# 8             1033.599976  ...              NaN                      <NA>
# 9             1026.000000  ...              NaN                      <NA>
#
#    total_precipitation  snow_depth    fog   rain   snow   hail  thunder  \
# 0                 0.01         NaN  False  False  False  False    False
# 1                 0.00         NaN  False  False  False  False    False
# 2                 0.04         NaN  False  False  False  False    False
# 3                 0.00         NaN  False  False  False  False    False
# 4                 0.04         NaN  False  False  False  False    False
# 5                 0.00         NaN  False  False  False  False    False
# 6                 0.00         NaN   True   True   True   True     True
# 7                 0.00         NaN  False  False  False  False    False
# 8                 0.00         1.6  False  False  False  False    False
# 9                 0.35         NaN  False  False  False  False    False
#
#    tornado
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
#
# [10 rows x 31 columns]

# %%
# 10 highest total_precipitation samples
df.sort_values('total_precipitation', ascending=False).head(10)[['station_number', 'year', 'month', 'day', 'total_precipitation']]
# Out:
#       station_number  year  month  day  total_precipitation
# 632           594930  1992      6   13                 4.53
# 1139          973720  2008      2    9                 3.78
# 193           209630  1987     10   18                 3.50
# 1445          232050  1969      3   31                 2.76
# 1235          216360  1973      9   27                 2.17
# 1755          478970  1999      6   19                 2.17
# 1831          986180  1996     10    8                 2.13
# 1018          321660  1984      9   10                 1.57
# 176           478070  1963      8   28                 1.57
# 725            73740  1988     10    3                 1.54

# %% [markdown]
# # Use BigQuery through pandas-gbq
#
# The `pandas-gbq` library is a community led project by the pandas community. It covers basic functionality, such as writing a DataFrame to BigQuery and running a query, but as a third-party library it may not handle all BigQuery features or use cases.
#
# [Pandas GBQ Documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_gbq.html)

# %%
import pandas_gbq

df = pandas_gbq.read_gbq('''
  SELECT name, SUM(number) as count
  FROM `bigquery-public-data.usa_names.usa_1910_2013`
  WHERE state = 'TX'
  GROUP BY name
  ORDER BY count DESC
  LIMIT 100;
''', project_id=project_id, dialect='standard', progress_bar_type=None)

df.head()
# Out:
#       name   count
# 0    James  272793
# 1     John  235139
# 2  Michael  225320
# 3   Robert  220399
# 4    David  219028

# %% [markdown]
# # Syntax highlighting
# `google.colab.syntax` can be used to add syntax highlighting to any Python string literals which are used in a query later.

# %%
from google.colab import syntax

query = syntax.sql('''
SELECT
  COUNT(*) as total_rows
FROM
  `bigquery-public-data.samples.gsod`;
''')

pandas_gbq.read_gbq(
    query,
    project_id=project_id, dialect='standard', progress_bar_type=None)
# Out:
#    total_rows
# 0   114420316
